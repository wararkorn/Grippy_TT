# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('robot_to_chick2.csv')
data
# Out:
#      distance  width  height    diagonal  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0        92.0   42.0    52.0   66.843100         NaN         NaN         NaN
# 1         NaN    NaN     NaN         NaN         NaN         NaN         NaN
# 2        92.0   43.0    51.0   66.708320         NaN         NaN         NaN
# 3         NaN    NaN     NaN         NaN         NaN         NaN         NaN
# 4        91.0   42.0    52.0   66.843100         NaN         NaN         NaN
# ..        ...    ...     ...         ...         ...         ...         ...
# 296      44.0   89.0   106.0  138.408815         NaN         NaN         NaN
# 297       NaN    NaN     NaN         NaN         NaN         NaN         NaN
# 298      44.0   89.0   106.0  138.408815         NaN         NaN         NaN
# 299       NaN    NaN     NaN         NaN         NaN         NaN         NaN
# 300      40.0   90.0   109.0  141.354165         NaN         NaN         NaN
#
# [301 rows x 7 columns]

# %%
x = data['distance']
y = data['width']

plt.plot(x, y, marker='+', linestyle='-',color = 'r')  
plt.xlabel('Distance')  
plt.ylabel('Width')  
plt.title('Width Graph')  

plt.show()

# %%
x = data['distance']
y = data['height']

plt.plot(x, y, marker='+', linestyle='-',color = 'g')  
plt.xlabel('Distance')  
plt.ylabel('Height')  
plt.title('Height Graph')  

plt.show()

# %%
x = data['distance']
y = data['diagonal']

plt.plot(x, y, marker='+', linestyle='-',color = 'b')  
plt.xlabel('Distance')  
plt.ylabel('diagonal')  
plt.title('diagonal Graph')  

plt.show()
